# %%
def simple():
    print("My first function")

# %%
simple()
# Out:
# My first function

# %%
def plus_ten(a):
    return a + 10

# %%
plus_ten(2)
# Out:
# 12

# %%
plus_ten(5)
# Out:
# 15

# %%
def plus_ten(a):
    result = a + 10
    return result

# %%
plus_ten(2)
# Out:
# 12

# %%
def plus_ten(a):
    result = a + 10
    return "Outcome"
    return result

# %%
plus_ten(2)
# Out:
# 'Outcome'

# %%
def plus_ten(a):
    result = a + 10
    print("Outcome")
    return result

# %%
plus_ten(2)
# Out:
# Outcome
# 12

# %%
def wage(w_hours):
    return w_hours * 25

def with_bonus(w_hours):
    return wage(w_hours) + 50

# %%
wage(8),with_bonus(8)
# Out:
# (200, 250)

# %%
def add_10(m):
    if m >= 100:
        m = m + 10
        return m
    else:
        return "Save more!"

# %%
add_10(110)
# Out:
# 120

# %%
add_10(50)
# Out:
# 'Save more!'

# %%
def subtract_bc(a,b,c):
    result = a - b*c
    print('Paramenter a equals', a)
    print('Paramenter a equals', b)
    print('Paramenter a equals', c)
    return result

# %%
subtract_bc(10,3,2)
# Out:
# Paramenter a equals 10
# Paramenter a equals 3
# Paramenter a equals 2
# 4

# %%
subtract_bc(b=3,a=10,c=2)
# Out:
# Paramenter a equals 10
# Paramenter a equals 3
# Paramenter a equals 2
# 4

# %%
type(10)
# Out:
# int

# %%
int(5.0)
# Out:
# 5

# %%
float(3)
# Out:
# 3.0

# %%
str(500)
# Out:
# '500'

# %%
max(10,20,30)
# Out:
# 30

# %%
min(10,20,30)
# Out:
# 10

# %%
z = -20
abs(z)
# Out:
# 20

# %%
list_1 = [1,2,3,4]
sum(list_1)
# Out:
# 10

# %%
round(3.555,2)
# Out:
# 3.56

# %%
round(3.2)
# Out:
# 3

# %%
2 ** 10
# Out:
# 1024

# %%
pow(2,10)
# Out:
# 1024

# %%
len('Mathematics')
# Out:
# 11
