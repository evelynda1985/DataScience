# %%
False or not True and not False
# Out:
# False

# %%
True and not False and True or not False
# Out:
# True

# %%
True or False and False
# Out:
# True

# %%
False and True or False
# Out:
# False

# %%
10 is not 12
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\evely\AppData\Local\Temp\ipykernel_20352\2742155778.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   10 is not 12
# True

# %%
50 is 50
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\evely\AppData\Local\Temp\ipykernel_20352\4077015830.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   50 is 50
# True
