# %%
15 + 23
# Out:
# 38

# %%
26-50
# Out:
# -24

# %%
20/4
# Out:
# 5.0

# %%
22/4
# Out:
# 5.5

# %%
22 % 4
# Out:
# 2

# %%
float(22)/4
# Out:
# 5.5

# %%
6 * 8
# Out:
# 48

# %%
15 ** 2
# Out:
# 225
