# %%
Cars = ("BMW", "Dodge", "Ford")
Cars
# Out:
# ('BMW', 'Dodge', 'Ford')

# %%
Cars = ("BMW", "Dodge", "Ford")
Cars[1]
# Out:
# 'Dodge'

# %%
name, age = 'Peter,24'.split(',')
print(name)
print(age)
# Out:
# Peter
# 24

# %%
def rectangle_info(lenght, width):
    area = lenght * width
    perimeter = (2 * lenght) + (2 * width)
    return (area,perimeter)

print(rectangle_info(2,10))
# Out:
# (20, 24)
