# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
3 > 5 and 10 <= 20
# Out:
# False

# %%
True and not True
# Out:
# False

# %%
False or not True and True
# Out:
# False

# %%
True and not True or True
# Out:
# True

# %%
5 is 6
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\evely\AppData\Local\Temp\ipykernel_30052\2929037671.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   5 is 6
# False

# %%
5 == 6
# Out:
# False

# %%
5 is not 6
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\evely\AppData\Local\Temp\ipykernel_30052\2227521640.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   5 is not 6
# True

# %%
5 != 6
# Out:
# True
