# %%
x = 234
def size(x):
    if x > 200:
        print("Big")
    elif x > 100 and x <= 200:
        print("Average")
    else:
        print("Small")
size(x)
# Out:
# Big

# %%
x = 200
def size(x):
    if x > 200:
        print("Big")
    elif x > 100 and x <= 200:
        print("Average")
    elif x >= 0 and x <= 100:
        print("Small")
    else:
        print("Negative")
size(x)
# Out:
# Average
